# %%
import torch

# %%
torch.mps.is_available()
# Out:
# True

# %%
torch.mps.device_count()
# Out:
# 1

# %%
import numpy as np

arr = np.array([[1, 2, 3], 
                [4, 5, 6]])

arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr2 = torch.tensor(arr)
arr2
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
np.ones((1, 2))
# Out:
# array([[1., 1.]])

# %%
arr2.device
# Out:
# device(type='cpu')

# %%
arr2.to("mps")
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]], device='mps:0')
